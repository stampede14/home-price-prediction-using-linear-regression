# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
# %matplotlib inline

# %%
df = pd.read_csv("homeprices.csv")

# %%
plt.scatter(df.area, df.price , color  = 'red', marker = '+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
m= reg.coef_

# %%
b = reg.intercept_

# %%
plt.xlabel('area')
plt.xlabel('price')
plt.scatter(df.area , df.price , marker = '+')
plt.plot(df.area , reg.predict(df[['area']]) , color = 'blue')

# %%
d = pd.read_csv("areas.csv")

# %%
p = reg.predict(d)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
d['price']= p

# %%
d.to_csv("prediction.csv")

# %%
plt.xlabel('area')
plt.xlabel('price')
plt.scatter(df.area , df.price , marker = '+')
plt.plot(df.area , reg.prediction(area) , color = 'blue')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 4
#       2 plt.xlabel('price')
#       3 plt.scatter(df.area , df.price , marker = '+')
# ----> 4 plt.plot(df.area , reg.prediction(area) , color = 'blue')
#
# AttributeError: 'LinearRegression' object has no attribute 'prediction'

# %%
df = pd.read_csv("canada_per_capita_income.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
# Out:
#   Cell In[41], line 1
#     plt.scatter(df.year , df.percapitaincome (US$), color = 'red' , marker = '+')
#                                                 ^
# SyntaxError: invalid syntax

# %%
df.rename(columns = {'per capita income (US$)' : 'per_capita'}, inplace  = True)

# %%
plt.scatter(df.year , df.per_capita, color = 'red' , marker = '+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']], df.per_capita)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
